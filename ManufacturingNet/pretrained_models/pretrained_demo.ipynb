# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import ManufacturingNet
from ManufacturingNet.pretrained_models import ResNet

# %% [markdown]
# # Load Data

# %%
train_data=np.load('sample_CWRU_train.npy',allow_pickle=True)
dev_data=np.load('sample_CWRU_dev.npy',allow_pickle=True)

# %% [markdown]
# # Model

# %%
ResNet(train_data,dev_data)
# Out:
# Question [1/7]: No of classes:
#
#
# Please enter the number of classes for classification: 10
#
#
# ...
# Question [2/7]: Model Selection:
#
#
# Do you want pretrained model? (y/n): y
# Please enter any number between 1 to 5 to select the model:
# [1:ResNet18,2:ResNet34,3:ResNet50,4:ResNet101,5:ResNext50]3
# 1
#
#
# ...
# ResNet(
#   (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...
